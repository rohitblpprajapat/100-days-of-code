# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitblpprajapat/100-days-of-code/blob/master/Pytorch_Tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tensor: The Fundamental Data Structure of PyTorch (DL in general)**
#  * Multidimensional Array (ndarray) in Numpy
#  * Tensors in PyTorch

# %%
import torch

# %%
# help(torch)

# %%
print(torch.__version__)
# Out:
# 2.9.0+cpu

# %% [markdown]
# To know more: https://pytorch.org/get-started/pytorch-2.0/

# %% [markdown]
# # Some (Boring) things that you must be aware of

# %% [markdown]
# (From Python's view) What is the **torch** by the way?
#
#    * Is it a module, class, function, method..?

# %%
torch
# Out:
# <module 'torch' from '/usr/local/lib/python3.12/dist-packages/torch/__init__.py'>

# %% [markdown]
# What does a module contain?
#
#    * Function definitions
#    * Imports (namespace) of supporting packages
#    * Class definitions and so on
#
#
# **Note:** Module can be written in pure python and also in C/Cpp.

# %%
with open(torch.__file__) as file:
  print(file.read())
# Out:
# """
# The torch package contains data structures for multi-dimensional
# tensors and defines mathematical operations over these tensors.
# Additionally, it provides many utilities for efficient serialization of
# Tensors and arbitrary types, and other useful utilities.
#
# It has a CUDA counterpart, that enables you to run your tensor computations
# on an NVIDIA GPU with compute capability >= 3.0.
# """
#
# # mypy: allow-untyped-defs
#
# import builtins
# import ctypes
# import functools
# import glob
# import importlib
# import inspect
# import math
# import os
# import platform
# import sys
# import textwrap
# import threading
# from typing import (
#     Any as _Any,
#     Callable as _Callable,
#     get_origin as _get_origin,
#     Optional as _Optional,
#     overload as _overload,
#     TYPE_CHECKING,
#     TypeVar as _TypeVar,
#     Union as _Union,
# )
# from typing_extensions import ParamSpec as _ParamSpec, TypeIs as _TypeIs
#
#
# ...

# %% [markdown]
# * Let's see how many objects are callable in the **torch** module. <br>
# * Note, callable doesn't mean it should be a pure function and also it does not mean it should return something when called.
# * classes are callable (calling a class returns a new instance); instances are callable if their class has a __call__() method.

# %%
dir(torch)
# Out:
# ['AVG',
#  'AcceleratorError',
#  'AggregationType',
#  'AliasDb',
#  'AnyType',
#  'Argument',
#  'ArgumentSpec',
#  'AwaitType',
#  'BFloat16Storage',
#  'BFloat16Tensor',
#  'BenchmarkConfig',
#  'BenchmarkExecutionStats',
#  'Block',
#  'BoolStorage',
#  'BoolTensor',
#  'BoolType',
#  'BufferDict',
#  'ByteStorage',
#  'ByteTensor',
#  'CallStack',
#  'Capsule',
#  'CharStorage',
#  'CharTensor',
#  'ClassType',
#  'Code',
#  'CompilationUnit',
#  'CompleteArgumentSpec',
#  'ComplexDoubleStorage',
#  'ComplexFloatStorage',
#  'ComplexType',
#  'ConcreteModuleType',
#  'ConcreteModuleTypeBuilder',
#  'DeepCopyMemoTable',
#  'DeserializationStorageContext',
#  'DeviceObjType',
#  'DictType',
#  'DisableTorchFunction',
#  'DisableTorchFunctionSubclass',
#  'DispatchKey',
#  'DispatchKeySet',
#  'DoubleStorage',
#  'DoubleTensor',
#  'EnumType',
#  'ErrorReport',
#  'Event',
#  'ExcludeDispatchKeyGuard',
#  'ExecutionPlan',
#  'FatalError',
#  'FileCheck',
#  'FloatStorage',
# ...

# %%
counter = 0
for (i,attrib) in enumerate(dir(torch)):
  if callable(eval(f'torch.{attrib}')):
    print(attrib,sep='',end='\t')
    counter += 1
    if (i+1)%10 == 0:
      print('\n')
# Out:
# AcceleratorError	AggregationType	AliasDb	AnyType	Argument	ArgumentSpec	AwaitType	BFloat16Storage	BFloat16Tensor
#
# BenchmarkConfig	BenchmarkExecutionStats	Block	BoolStorage	BoolTensor	BoolType	BufferDict	ByteStorage	ByteTensor	CallStack
#
# Capsule	CharStorage	CharTensor	ClassType	Code	CompilationUnit	CompleteArgumentSpec	ComplexDoubleStorage	ComplexFloatStorage	ComplexType
#
# ConcreteModuleType	ConcreteModuleTypeBuilder	DeepCopyMemoTable	DeserializationStorageContext	DeviceObjType	DictType	DisableTorchFunction	DisableTorchFunctionSubclass	DispatchKey	DispatchKeySet
#
# DoubleStorage	DoubleTensor	EnumType	ErrorReport	Event	ExcludeDispatchKeyGuard	ExecutionPlan	FatalError	FileCheck	FloatStorage
#
# FloatTensor	FloatType	FunctionSchema	Future	FutureType	Generator	GradScaler	Gradient	Graph	GraphExecutorState
#
# HalfStorage	HalfTensor	IODescriptor	InferredType	IntStorage	IntTensor	IntType	InterfaceType	JITException	ListType
#
# ...

# %% [markdown]
# * It seems, there are so many methods and functions to learn. However, we use only a few (say 100+) of them. Fortunately we can group them into a few categories as given in the documentation [page](https://pytorch.org/docs/stable/torch.html). <br>
#
# * However, did you notice some familiar names in the output list of callables? 😀

# %%
print('Number of callables in the module is: ',counter)
# Out:
# Number of callables in the module is:  1270

# %% [markdown]
# ## Tensor

# %%
type(torch.tensor)
# Out:
# builtin_function_or_method

# %% [markdown]
# * Observe that the type is `builtin_function_or_method ` **not** a native python function.

# %%
type(abs)
# Out:
# builtin_function_or_method

# %% [markdown]
# * We can define native python functions in a module and import them in the main script
#
# * Let's see what is the type of such functions

# %%
! touch calc.py
#open the file and define some functions there
# def foo():
#   pass

# class myclass:

#   def __init__(self,a,b):
#     self.a = 1
#     self.b =1

#   def foo(self):
#     pass

# %%
import importlib
import calc
importlib.reload(calc)
# Out:
# <module 'calc' from '/content/calc.py'>

# %% [markdown]
# Are all the torch functions built-in (i.e., written in c/cpp)?
#
#   * not necessarily

# %%
print(type(torch.is_tensor))
# Out:
# <class 'function'>

# %% [markdown]
# Then, how many of them are built-in then?.
#
#   * Roughly, $\frac{3}{4}$-th

# %%
import types
counter = 0
for (i,attrib) in enumerate(dir(torch)):
  if isinstance(eval(f'torch.{attrib}'),types.BuiltinFunctionType):
    print(attrib,sep='',end='\t')
    counter += 1
    if (i+1)%10 == 0:
      print('\n')
# Out:
# _adaptive_avg_pool2d
#
# _adaptive_avg_pool3d	_add_batch_dim	_add_relu	_add_relu_	_addmm_activation	_aminmax	_amp_foreach_non_finite_check_and_unscale_	_amp_update_scale_	_assert_async	_assert_scalar	_assert_tensor_metadata	_batch_norm_impl_index	_cast_Byte	_cast_Char	_cast_Double	_cast_Float	_cast_Half
#
# _cast_Int	_cast_Long	_cast_Short	_choose_qparams_per_tensor	_chunk_cat	_coalesce	_compute_linear_combination	_conj	_conj_copy
#
# _conj_physical	_convert_indices_from_coo_to_csr	_convert_indices_from_csr_to_coo	_convert_weight_to_int4pack	_convert_weight_to_int4pack_for_cpu	_convolution	_convolution_mode	_copy_from	_copy_from_and_resize
#
# _cslt_compress	_cslt_sparse_mm	_cslt_sparse_mm_search	_ctc_loss	_cudnn_ctc_loss	_cudnn_init_dropout_state	_cudnn_rnn	_cudnn_rnn_flatten_weight	_cufft_clear_plan_cache	_cufft_get_plan_cache_max_size
#
# _cufft_get_plan_cache_size	_cufft_set_plan_cache_max_size	_cummax_helper	_cummin_helper	_debug_has_internal_overlap	_dim_arange
#
# ...

# %%
print(counter)
# Out:
# 1004

# %% [markdown]
# Ok enough of all these!. Let's move on

# %% [markdown]
# # Creating a tensor object
#
#    * tensor objects have **support** to autograd, runs in GPU, etc..
#    * Suppose we convert *torch tensor to numpy array* then we losse all those features.
#    * Therefore, be aware of the data type of the objects that you are manipulating to avoid conflicts.

# %%
help(torch.tensor)
# Out:
# Help on built-in function tensor in module torch:
#
# tensor(...)
#     tensor(data, *, dtype=None, device=None, requires_grad=False, pin_memory=False) -> Tensor
#
#     Constructs a tensor with no autograd history (also known as a "leaf tensor", see :doc:`/notes/autograd`) by copying :attr:`data`.
#
#     .. warning::
#
#         When working with tensors prefer using :func:`torch.Tensor.clone`,
#         :func:`torch.Tensor.detach`, and :func:`torch.Tensor.requires_grad_` for
#         readability. Letting `t` be a tensor, ``torch.tensor(t)`` is equivalent to
#         ``t.detach().clone()``, and ``torch.tensor(t, requires_grad=True)``
#         is equivalent to ``t.detach().clone().requires_grad_(True)``.
#
#     .. seealso::
#
#         :func:`torch.as_tensor` preserves autograd history and avoids copies where possible.
#         :func:`torch.from_numpy` creates a tensor that shares storage with a NumPy array.
#
#     Args:
# ...

# %%
# 0 dim or degree or rank tensor (rank has nothing to do with matrix rank)
x = torch.tensor(9)
print(x,x.shape,x.ndim)
# Out:
# tensor(9) torch.Size([]) 0

# %%
x[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3629782281.py in <cell line: 0>()
# ----> 1 x[0]
#
# IndexError: invalid index of a 0-dim tensor. Use `tensor.item()` in Python or `tensor.item<T>()` in C++ to convert a 0-dim tensor to a number

# %%
print(x.storage())
# Out:
#  9
# [torch.storage.TypedStorage(dtype=torch.int64, device=cpu) of size 1]
# /tmp/ipython-input-3799332687.py:1: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   print(x.storage())

# %% [markdown]
# Pytorch now depreciated TypedStorage. Let's supress too much warning about the same class

# %%
torch.set_warn_always(False)

# %%
print(x.stride())
# Out:
# ()

# %%
x = torch.tensor([9])
print(x,x.shape,x.ndim)
# Out:
# tensor([9]) torch.Size([1]) 1

# %%
x[0]
# Out:
# tensor(9)

# %%
print(x.storage())
print(x.stride())
# Out:
#  9
# [torch.storage.TypedStorage(dtype=torch.int64, device=cpu) of size 1]
# (1,)

# %%
x = torch.tensor([[9]])
print(x,x.shape,x.ndim)
# Out:
# tensor([[9]]) torch.Size([1, 1]) 2

# %% [markdown]
# What do you get if you access x[0]?
#
#   * Not just 9, it is a tensor of dim-1

# %%
print(x[0])
# Out:
# tensor([9])

# %% [markdown]
# ndim == len(x.shape)

# %%
x = torch.tensor([[[9]]])
print(x,x.shape,x.ndim)
# Out:
# tensor([[[9]]]) torch.Size([1, 1, 1]) 3

# %%
print(x[0])
# Out:
# tensor([[9]])

# %% [markdown]
# **Vector** (Tensor of degree 1)

# %%
x = torch.randint(0,3,size=(2,),generator=torch.manual_seed(42))
print(x, x.shape, x.ndim)
# Out:
# tensor([0, 2]) torch.Size([2]) 1

# %% [markdown]
# **Matrix** (tensor of Degree 2)

# %%
x = torch.randint(0,3,size=(2,2),generator=torch.manual_seed(42))
print(x, x.shape, x.ndim)
# Out:
# tensor([[0, 2],
#         [1, 1]]) torch.Size([2, 2]) 2

# %% [markdown]
# ## Storage
#
#  * Multidimensional arrays are stored in a linear storage (that is all elements are contiguous)
#  * We have two options, either we follow row-major or column-major layout.
#  * To know more: https://en.wikipedia.org/wiki/Row-_and_column-major_order

# %%
x.storage() # row major
# Out:
#  0
#  2
#  1
#  1
# [torch.storage.TypedStorage(dtype=torch.int64, device=cpu) of size 4]

# %%
x.stride()
# Out:
# (2, 1)

# %% [markdown]
#  * The stride for the 0th dim is 2 and the last dim is 1

# %%
row = 1
col = 1
row_stride = 2
col_stride = 1
x.storage()[row*row_stride + col*col_stride]
# Out:
# 1

# %%
x.view(2,2)
# Out:
# tensor([[0, 2],
#         [1, 1]])

# %% [markdown]
# **Tensor** (of degree 3)
#
#   * Print each element in axis=0 (0th dimension).
#   * Each element in the zeroth dimention is a tensor of degree-2 (ndim-1, in general)

# %%
x = torch.randint(0,3,size=(2,2,2),generator=torch.manual_seed(42))
print(x, x.shape, x.ndim)
# Out:
# tensor([[[0, 2],
#          [1, 1]],
#
#         [[0, 2],
#          [1, 2]]]) torch.Size([2, 2, 2]) 3

# %%
x.storage()
# Out:
#  0
#  2
#  1
#  1
#  0
#  2
#  1
#  2
# [torch.storage.TypedStorage(dtype=torch.int64, device=cpu) of size 8]

# %%
x.stride()
# Out:
# (4, 2, 1)

# %% [markdown]
# Moving from right to left,
#
# * The stride for the rightmost dimension (dim 2, in this case) is always 1
# * Then for dim-1 it is `x.size[-1]` = 2
# * Then for dim-0 it is `x.size[-1]*x.size[-2]` = 2*2=4

# %% [markdown]
# **Tesnor** of Degree 4
#
#   * We have no other option other than displaying elements in the dim-0 (axis-0) in a nice readable format (i.e., using nested square brackets).

# %%
x = torch.randint(0,3,size=(2,2,2,2),generator=torch.manual_seed(42))
print(x, x.shape, x.ndim)
# Out:
# tensor([[[[0, 2],
#           [1, 1]],
#
#          [[0, 2],
#           [1, 2]]],
#
#
#         [[[1, 2],
#           [1, 1]],
#
#          [[2, 0],
#           [0, 1]]]]) torch.Size([2, 2, 2, 2]) 4

# %% [markdown]
# Often, we don't need to go beyond a tensor of degree greater than 4.

# %% [markdown]
# ## Why do we need to know about the logical (view) and physical representations using stride?
#
#   * Suppose that we want to access diagonal elements of a matrix.
#   * Assume that we don't have any methods to access the diagonal elements.
#   * Naturally,we tend to loop over the matrix
#   * Stride gives us the shortcut

# %%
mat =torch.randint(0,3,size=(4,4),generator=torch.manual_seed(42))
print(mat)
# Out:
# tensor([[0, 2, 1, 1],
#         [0, 2, 1, 2],
#         [1, 2, 1, 1],
#         [2, 0, 0, 1]])

# %%
mat.diag()
# Out:
# tensor([0, 2, 1, 1])

# %% [markdown]
# SInce all the elements are stored in a row major form, we know that using stride value of 5 gives the diagonal elements.

# %%
mat.storage()
# Out:
#  0
#  2
#  1
#  1
#  0
#  2
#  1
#  2
#  1
#  2
#  1
#  1
#  2
#  0
#  0
#  1
# [torch.storage.TypedStorage(dtype=torch.int64, device=cpu) of size 16]

# %%
print(mat.as_strided([4],stride=[5]))
# Out:
# tensor([0, 2, 1, 1])

# %%
print(mat.as_strided([4],stride=[5]).stride())
# Out:
# (5,)

# %% [markdown]
# If you figured out the pattern, think about using strides first.

# %% [markdown]
# **Exercise:** Implement the convolution operation using strides (this is a convenient  way of doing it)

# %% [markdown]
# Is transposing the matrix costly?
#
#  * No, transposing just changes the strides!
#  * If $x \rightarrow $ stride:[3,1], then $x^T \rightarrow $stride[1,3]
#  * It doesn't create any empty  matrix and displace elements from original matrix like we tend to think.

# %% [markdown]
# # What happesn if we assign a tensor to an another tensor?
#
#   * Tensor by default only gives "view" of the tensor being re-assigned
#   * Do clone if you need a copy of tensor (remember the memory requirement while doing so)

# %%
from collections import OrderedDict

# %%
_parameters = OrderedDict()
_parameters['w1']=torch.randn(size=(2,2))
w2 = _parameters['w1']
print(torch.allclose(w2,_parameters['w1']))
print(w2 is _parameters['w1'])
print(id(w2), id(_parameters['w1']))
# Out:
# True
# True
# 133470649780736 133470649780736

# %%
def Parameter():
  _parameters = OrderedDict()
  _parameters['w1']=torch.randn(size=(2,2))
  print(_parameters['w1'])
  _parameters['w2']=torch.randn(size=(2,2))
  _parameters['w3']=torch.randn(size=(2,2))
  for value in _parameters.values():
    yield value

# %%
w1,w2,w3 = list(Parameter())
w1.

# %% [markdown]
# #**Unary operations** on Tensor
#
#   * Unlike a scalar (vector or matrix), what we have now are tensors. Therefore, there are many possible unary operations we can carry out on tensors.
#
#   * The frequently used unary operations are negating, finding the max or argmax, index of an element, transpose the tensor, swapping the axis...
#
#   * These operations are further grouped into two types
#    * **Reduction operations (reduce the size of array)**: argmin, amin, argmax, amax, dist,mean, sum,nansum,mode,unique
#    * **Pointwise operations (does not change the shape of the tensor)**: Functions (sin,cos, atan..), logical (and,or,not,..), abs,pow,div,frac,clamp,...
#   * we can either use inplace methods or functions (torch.functionName())

# %%
x =
y = x

# %%
# x is from the previous execution
print(x)

# %% [markdown]
# ## Summing

# %% [markdown]
# * If we have a vector, summing it results in a scalar (dim-1 to dim-0)
# * If we have a matrix $m \times n$, then summing along axis-0 will result in dim-1 vector of size $m$. (axis-1 results in dim-1 of size $n$)

# %%
vector = torch.tensor([1,2,3,4.0])
print(vector.ndim)
torch.sum(vector)
print(torch.sum(vector).ndim)

# %%
print(torch.sum(x))

# %%
print(x)

# %%
print(torch.sum(x,axis=0)) # sum the elements in axis 0, axis 0 contains 2 elements of each size 2 x 2 x 2, so the result is also of same size
print(torch.sum(x,axis=0).shape) # note the change in shape after adding results

# %% [markdown]
# What if we don't want to change the dim of the returned array? keep the original dimension of $x$.

# %%
print(torch.sum(x,axis=0,keepdim=True))
print(torch.sum(x,axis=0,keepdim=True).shape)

# %%
print(torch.sum(x,axis=1))#sum the elements in axis 1, axis 1 contains 2 elements of each size 2 x 2, so the result is also of same size
print(torch.sum(x,axis=1).shape)

# %%
print(torch.sum(x,axis=2))
print(torch.sum(x,axis=2).shape)

# %%
print(torch.sum(x,axis=3))
print(torch.sum(x,axis=3).shape)

# %% [markdown]
# Suppose we **do not know** the dim of an array (as happens in the intermediate computations). However, we want to sum the elements along the last dimension. What do you do then?. The straightforward approach is to use python flexible indexing schemes

# %%
print(torch.sum(x,axis=-1))
print(torch.sum(x,axis=-1).shape)

# %% [markdown]
# # Binary Operations

# %% [markdown]
# Let's take a tough problem. <br>
# * We have $x$ of shape $2 \times 2 \times 2 \times 2$
# * Suppose i have an another tensor of same size (shape). Then I can do element wise multiplication or matrix multiplication along a particular axis.

# %% [markdown]
# Elementwise multiplication. <br>
# * Output size = $2 \times 2 \times 2 \times 2$

# %%
print(x)

# %%
y = torch.randint(0,3,size=(2,2,2,2),generator=torch.manual_seed(10))
print(y)

# %%
print(torch.mul(x,y))

# %% [markdown]
# What happens if we do a matrix multiplication?
#
#   * What is the dimension?

# %%
print(torch.matmul(x,y))

# %%
print(x[0,0,:,:])
print(y[0,0,:,:])

# %%
print(torch.matmul(x[0,0,:,:],y[0,0,:,:]))

# %% [markdown]
# Let's change the dimension of y to $2 \times 2 \times 2 \times 4$

# %%
y = torch.randint(0,3,size=(2,2,2,4),generator=torch.manual_seed(10))
print(y)

# %%
print(torch.matmul(x,y))

# %%
print(torch.matmul(x[0,0,:,:],y[0,0,:,:]))

# %% [markdown]
# Dimension compatibility is by default checked for last two dimensions of the tensors being multiplied

# %%
y = torch.randint(0,3,size=(2,2,4,4),generator=torch.manual_seed(10))
print(torch.matmul(x,y))

# %% [markdown]
# Note the words in error message: Batch-2, first two dimensions.. because

# %%
y = torch.randint(0,3,size=(2,3,4,4),generator=torch.manual_seed(10))
print(torch.matmul(x,y))

# %% [markdown]
# **Singleton dim** is the one where the size of dim is 1

# %%
y = torch.randint(0,3,size=(4,2,4,4),generator=torch.manual_seed(10))
print(torch.matmul(x,y))

# %%
y = torch.randint(0,3,size=(2,1,2,4),generator=torch.manual_seed(10))
print(torch.matmul(x,y))

# %% [markdown]
# # Load image

# %%
from PIL import Image
import requests
from io import BytesIO
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# * We often need to convert tensor type from one format to the other say, torch to numpy. Underthehood, they use zero-copy interoperability protocol called [buffer protocol](https://docs.python.org/3/c-api/buffer.html) recommended by python.
#
# * Therefore, those operations are not **memory/computational** intensive.

# %%
response = requests.get("https://media.istockphoto.com/photos/beautiful-lionhead-goldfish-swimming-in-the-aquarium-picture-id905382158")
img = Image.open(BytesIO(response.content))
img = np.array(img)

# %%
plt.imshow(img)
plt.show()

# %%
t_img = torch.tensor(img)
print(t_img.shape)

# %% [markdown]
#  * Each element is of size 1024 x 3. That is, it still follows row major order where it takes rows in all 3 dimensions.
#
#  * Let's do transpose (again, it is not a computational intensive operation, it is just manipulating stride, offset,..)

# %%
t_img_T =  t_img.T
plt.imshow(np.array(t_img_T))
plt.show()

# %%
t_img_T =  torch.transpose(t_img,dim0=1,dim1=0)
plt.imshow(np.array(t_img_T))
plt.show()

# %% [markdown]
# What if we want to transpose more than 2 dims? We call that permute...

# %%
t_img_T =  torch.permute(t_img,(1,0,2))
plt.imshow(np.array(t_img_T))
plt.show()
